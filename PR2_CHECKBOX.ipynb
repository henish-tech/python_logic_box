# %%
def display_welcome():
    print("")
    print("Welcome to the Smart Console")
    print("-----------------------------")
    print("Your fun toolkit for basic logic operations!\n")

def display_menu():
    print("\nSelect an option:")
    print("1. Generate a Reverse Pattern")
    print("2. Check Prime Numbers in a Range")
    print("3. Find Factorial of a Number")
    print("4. Exit")

def reverse_pattern():
    try:
        rows = int(input('Enter the number of rows for the reverse pattern: '))
        if rows <= 0:
            print('Row count must be a positive number.')
            return
        print('\nReverse Pattern:')
        for i in range(rows, 0, -1):
            print('*' * i)
    except ValueError:
        print('Invalid input. Please enter a valid number.')

def prime_range():
    try:
        start = int(input('Enter the start of the range: '))
        end = int(input('Enter the end of the range: '))
        if start > end:
            print('Start must be less than or equal to end.')
            return
        print(f'\nPrime numbers between {start} and {end}:')
        for num in range(start, end + 1):
            if num > 1:
                for i in range(2, int(num ** 0.5) + 1):
                    if num % i == 0:
                        break
                else:
                    print(num, end=' ')
        print()
    except ValueError:
        print('Invalid input. Please enter numbers only.')

def factorial_finder():
    try:
        num = int(input('Enter a number to find its factorial: '))
        if num < 0:
            print('Factorial is not defined for negative numbers.')
            return
        factorial = 1
        for i in range(1, num + 1):
            factorial *= i
        print(f'The factorial of {num} is: {factorial}')
    except ValueError:
        print('Invalid input. Please enter a valid number.')

def main():
    display_welcome()
    while True:
        display_menu()
        choice = input('Enter your choice: ')
        if choice == '1':
            reverse_pattern()
        elif choice == '2':
            prime_range()
        elif choice == '3':
            factorial_finder()
        elif choice == '4':
            print('Exiting the Smart Console. Goodbye!')
            break
        else:
            print('Invalid choice. Please enter a number between 1 and 4.')

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Smart Console
# -----------------------------
# Your fun toolkit for basic logic operations!
#
#
# Select an option:
# 1. Generate a Reverse Pattern
# 2. Check Prime Numbers in a Range
# 3. Find Factorial of a Number
# 4. Exit
# Enter your choice:  1
# Enter the number of rows for the reverse pattern:  2
# Reverse Pattern:
# **
# *
#
# Select an option:
# 1. Generate a Reverse Pattern
# 2. Check Prime Numbers in a Range
# 3. Find Factorial of a Number
# 4. Exit
# Enter your choice:  3
# Enter a number to find its factorial:  4
# The factorial of 4 is: 24
#
# Select an option:
# 1. Generate a Reverse Pattern
# 2. Check Prime Numbers in a Range
# 3. Find Factorial of a Number
# 4. Exit
